# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Gaurav\OneDrive\Desktop\codsoft\dataset\Titanic-Dataset.csv",index_col="PassengerId")
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df.head(3)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.tail()
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 887                 0       2                     Montvila, Rev. Juozas
# 888                 1       1              Graham, Miss. Margaret Edith
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                     Behr, Mr. Karl Howell
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# PassengerId
# 887            male  27.0      0      0      211536  13.00   NaN        S
# 888          female  19.0      0      0      112053  30.00   B42        S
# 889          female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 890            male  26.0      0      0      111369  30.00  C148        C
# 891            male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.size
# Out:
# 9801

# %%
df.shape
# Out:
# (891, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# STEP 3-PERFORM EDA(DATA EXPLORATARY ANALYSIS)

# %%
df.isnull().sum()*100
# Out:
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age         17700
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Cabin       68700
# Embarked      200
# dtype: int64

# %% [markdown]
# df['Age'].fillna(df['Age'].mean(), inplace=True)

# %%
df=df.drop(columns="Cabin", axis=1)

# %%
df['Embarked'].fillna(df['Embarked'].mode()[0],inplace=True)
# Out:
# C:\Users\Gaurav\AppData\Local\Temp\ipykernel_10192\4031226428.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].fillna(df['Embarked'].mode()[0],inplace=True)

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
# Out:
# C:\Users\Gaurav\AppData\Local\Temp\ipykernel_10192\694922604.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       891 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Embarked  891 non-null    object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 76.6+ KB

# %%
df.shape
# Out:
# (891, 10)

# %%
df.hist(bins=50,figsize=(10,10))
plt.show()

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
plt.rcParams['figure.figsize']=(6,6)

# %%
sns.countplot(x="Survived", data=df,palette=['green','blue'])
plt.show()
# Out:
# C:\Users\Gaurav\AppData\Local\Temp\ipykernel_10192\3871505298.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Survived", data=df,palette=['green','blue'])

# %%
sns.countplot(x='Sex',data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
survived_count=df[df["Survived"]==1]["Sex"].value_counts().sort_index()
not_survived_count=df[df["Survived"]==0]["Sex"].value_counts().sort_index()

# %%
plt.style.use('dark_background')
plt.plot(survived_count.index,survived_count.values,marker="o",color="green",linestyle='-')
plt.plot(not_survived_count.index,survived_count.values,marker="p",color="red",linestyle='-')
plt.ylabel("count ",weight='bold')
plt.xlabel('sex',weight='bold')
plt.title("survival count by sex ",weight='bold')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
women=df[(df['Sex']=='female')&(df['Survived']==1)]

men=df[(df['Sex']=='male')&(df['Survived']==1)]

# %%
total_women=women.shape[0]
print(f"no of women survived:{total_women}")
total_men=men.shape[0]
print(f"no of men survived:{total_men}")
# Out:
# no of women survived:233
# no of men survived:109

# %%
sns.countplot(x='Pclass',data=df,palette=['red','purple','yellow'])
# Out:
# C:\Users\Gaurav\AppData\Local\Temp\ipykernel_10192\4084262326.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Pclass',data=df,palette=['red','purple','yellow'])
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x='Pclass',hue='Survived',data=df,palette=['red','cyan'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x='SibSp',hue='Survived',data=df)
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
df['Sex_encoded']=le.fit_transform(df['Sex'])
df['Embarked_encoded']=le.fit_transform(df['Embarked'])

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# ...

# %%
x=df.drop(columns=['Name','Sex','Embarked','Ticket'])
y=df['Survived']

# %%
sns.heatmap(x.corr(),  annot=True,linewidth=.5,cmap="crest")
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# Survived            0
# Pclass              0
# Name                0
# Sex                 0
# Age                 0
# SibSp               0
# Parch               0
# Ticket              0
# Fare                0
# Embarked            0
# Sex_encoded         0
# Embarked_encoded    0
# dtype: int64

# %%
plt.subplots(figsize=(15,7))
sns.lineplot(x='Fare',y='Survived',data=df)
# Out:
# <Axes: xlabel='Fare', ylabel='Survived'>

# %%
sns.scatterplot(data=df,x='Fare',y='Parch',hue='Survived',palette=['green','blue'])
# Out:
# <Axes: xlabel='Fare', ylabel='Parch'>

# %%
sns.scatterplot(x='SibSp',y='Parch',data=df,hue='Survived',palette=['red','yellow'])
# Out:
# <Axes: xlabel='SibSp', ylabel='Parch'>

# %%
sns.histplot(df['SibSp'],kde=True)
df.SibSp.skew()
# Out:
# 3.6953517271630565

# %%
df.to_csv('titanic_cleaned_data_csv')

# %%
df.isnull().sum()
# Out:
# Survived            0
# Pclass              0
# Name                0
# Sex                 0
# Age                 0
# SibSp               0
# Parch               0
# Ticket              0
# Fare                0
# Embarked            0
# Sex_encoded         0
# Embarked_encoded    0
# dtype: int64
